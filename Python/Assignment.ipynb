# %% [markdown]
# 1) What are the types of Applications?
# Ans. Desktop Application: install on the laptop/desktop, Mobile application: specially designed for mobile or tablet, Web Application: Accessed via bowser without installation, Cloud-based Application: hosted on remote server and delicered via cloud, Hybrid Applications: combination of Web and native applications
#
# 2) What is programing?
# Ans. Programming is the process of creating instructions, or code, that tell a computer how to perform specific tasks and solve problems
#
# 3) What is Python?
# Ans. Python is a popular, high-level, interpreted programming language known for its simple, readable syntax that emphasizes code clarity and reduced maintenance costs.

# %%
# 4) Write a Python program to check if a number is positive, negative or zero.
num = int(input("enter the number:"))

if num == 0:
    print("number is zero")
elif num > 0:
    print("positive number")
else :
    print("negative number")

# %%
# 5)Write a Python program to get the Factorial number of given numbers.
num = int(input("enter the number for factorial: "))
mul = 1
for i in range(1, num + 1):
    mul = mul * i
    i +=1
print(f"factorial of {num} is {mul} ")

# %%
# 6)Write a Python program to get the Fibonacci series of given range.
n = int(input("enter limit: "))
a = 0
b = 1
i = 1
while i <= n:
    print(a)
    c = a + b
    a = b
    b = c
    i = i + 1

# %% [markdown]
# 7) How memory is managed in Python?
# Ans. Memory in Python is managed automatically through a private heap, reference counting, and a generational garbage collector. This multi-layered system abstracts low-level details while optimizing for common programming patterns.
#
# 8) What is the purpose continuing statement in python?
# Ans. continue statement is used to skip that perticular statement

# %%
# 9) Write python program that swap two number with temp variable
a = int(input("enter the number:"))
b = int(input("enter the number:"))
c = 0
print("before swap",a)
print("before swap",b)
c = b
b = a
a = c
print("after the swap")
print("first",a)
print("second",b)

# %%
# 9) Write python program that swap two number without temp variable.
a = int(input("enter the number:"))
b = int(input("enter the number:"))
print("before swap",a)
print("before swap",b)
a,b = b, a
print("after the swap")
print("first",a)
print("second",b)

# %%
# 10) Write a Python program to find whether a given number is even or odd, print out an appropriate message to the user.
num = int(input("enter the number:"))

if num % 2 == 0:
    print("number is even")
else :
    print("number is odd")

# %%
# 11) Write a Python program to test whether a passed letter is a vowel or not.
let = input("enter the one letter:").lower()
vowel = "aeiou"
if len(let) > 1:
    print("please enter only one letter....")
else :
    if let in vowel:
        print("given character is vowel.")
    else: 
        print("given character is not a vowel.")

# %%
# 12) Write a Python program to sum of three given integers. However, if two values are equal sum will be zero.
num1 = int(input("enter the number:"))
num2 = int(input("enter the number:"))
num3 = int(input("enter the number:"))

def func1():
    if num1 == num2 or num2 == num3 or num3 == num1:
        return 0
    else:
        return num1 + num2 + num3

func1()

# %%
# 13) Write a Python program that will return true if the two given integer values are equal or their sum or difference is 5.
num1 = int(input("enter the number:"))
num2 = int(input("enter the number:"))

def func1():
    if num1 == num2 or num1 + num2 == 5 or num1 - num2 == 5:
        return True
    
func1()

# %%
# 14)Write a python program to sum of the first n positive integers.
num = int(input("enter the number:"))
sum = 0 
if num > 0 :
    for i in range(num + 1):
        sum += i
        i += 1
    print("total:",sum) 
else:
    print("enter the positive number")

# %%
# 15)Write a Python program to calculate the length of a string.
st = input("enter the string:")
print("lenght of the string:",len(st))

# %%
# 16) Write a Python program to count the number of characters in a string
st = input("enter the string:")
count = 0

for char in st:
    count +=1
print(count)

# %% [markdown]
# 17) What are negative indexes and why are they used?
# Ans. Negative index is used to access value from last. it used to reverse or to access the values from last

# %%
# 18)Write a Python program to count occurrences of a substring in a string.
st = input("enter the text about pollution:")
print("total number of occurence of pollution:",st.count("Pollution"))

# %%
# 19) Write a Python program to count the occurrences of each word in a given sentence
text = """Pollution is the introduction of contaminants into the natural environment 
that cause harm. Pollution can take the form of any substance solid liquid or gas 
or energy such as radioactivity heat sound or light Pollutants the components of 
pollution can be either foreign substances energies or naturally occurring contaminants"""

# convert to lowercase
text = text.lower()

# split into words
words = text.split()

# count words
word_count = {}

for word in words:
    word_count[word] = word_count.get(word, 0) + 1

print(word_count)

# %%
# 20) Write a Python program to get a single string from two given strings, separated by a space and swap the first two characters of each string.
st1 = input('enter the string:')
st2 = input('enter the string:')
print("combined string:", st1 + " " +st2)
ch1 = st1[0]
ch2 = st2[0]
print(st1.replace(st1[0],ch2))
print(st2.replace(st2[0],ch1))

# %%
# 21) Write a Python program to add 'in' at the end of a given string (length should be at least 3). 
# If the given string already ends with 'ing' then add 'ly' instead if the string length of the given string is less than 3, leave it unchanged.
def modify_string(s):
    if len(s) < 3:
        return s
    elif s.endswith("ing"):
        return s + "ly"
    else:
        return s + "ing"


# examples
print(modify_string("go"))       # less than 3 → unchanged
print(modify_string("play"))     # add "ing"
print(modify_string("playing"))  # ends with "ing" → add "ly"

# %%
# 22) Write a Python function to reverses a string if its length is a multiple of 4.
st1 = input("enter the string:")
if len(st1) % 4 == 0:
    print("reversed string:",st1[::-1])

# %%
# 23) Write a Python program to get a string made of the first 2 and the last 2 chars from a given a string. 
# If the string length is less than 2, return instead of the empty string.
def first_last_2(s):
    if len(s) < 2:
        return ""
    return s[:2] + s[-2:]


print(first_last_2("Python"))
print(first_last_2("JS"))       
print(first_last_2("A"))

# %%
# 24)Write a Python function to insert a string in the middle of a string.
def insert_middle(main_str, insert_str):
    mid = len(main_str) // 2
    return main_str[:mid] + insert_str + main_str[mid:]


print(insert_middle("HelloWorld", " "))     
print(insert_middle("Python", "123"))
print(insert_middle("<<>>", "TEXT"))

# %% [markdown]
# 25) What is List? How will you reverse a list?
# Ans. list is the collection of the different data types. we can reverse the list with reverse() function.
#
# 26) How will you remove last object from a list?
# Ans. we can remove last object with help of pop() function.
#
# 27) Suppose list1 is [2, 33, 222, 14, 25]. what is list1 [-1]?
# Ans. 25
#
# 28) Differentiate between append () and extend () methods?
# Ans. append() insert value at last. whereas extend() allow to extend the lenght of list by inserting value. in append() we can add only one value where with extend() function you can add as many as value you want.
#
# 29) Write a Python function to get the largest number, smallest num and sum of all from a list.
# Ans. to find the largest number use max() function, to find smallest number use min() function and for addition use sum() function
#
# 30) How will you compare two lists?
# Ans. with equal to (==) operation

# %%
# 31) Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings.
def count_strings(lst):
    count = 0
    
    for s in lst:
        if len(s) >= 2 and s[0] == s[-1]:
            count += 1
            
    return count


words = ["abc", "aba", "1221", "xy", "aa", "a"]
print(count_strings(words))

# %%
# 32)Write a Python program to remove duplicates from a list.
lst = [15,48,59,78,68,78,78,59,12,79,48]
print(lst)
print(set(lst))

# %%
# 33)Write a Python program to check a list is empty or not.
lst1 = []
lst2 = [12, 45]

if len(lst1) == 0:
    print("List is empty.")
else :
    print("Not Empty")

if len(lst2) == 0:
    print("List is empty.")
else :
    print("Not Empty")

# %%
# 34) Write a Python function that takes two lists and returns true if they have at least one common member.
lst1 = [12, 45]
lst2 = [12, 45]

def compare(lst1, lst2):
    for i in lst1:
        if i in lst2:
            return True
    return False

print(compare(lst1, lst2))

# %%
# 35) Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30.
squares = [i**2 for i in range(1, 31)]

print("First 5:", squares[:5])
print("Last 5:", squares[-5:])

# %%
# 36) Write a Python function that takes a list and returns a new list with unique elements of the first list.
def unique_list(lst):
    return list(set(lst))

print(unique_list([1, 2, 2, 3, 4, 4]))

# %%
# 37)Write a Python program to convert a list of characters into a string.
chars = ['P', 'y', 't', 'h', 'o', 'n']
result = ''.join(chars)

print(result)

# %%
# 38)Write a Python program to select an item randomly from a list.
import random

lst = [10, 20, 30, 40]
print(random.choice(lst))

# %%
# 39)Write a Python program to find the second smallest number in a list.
lst = [4, 1, 7, 2, 1]

unique_sorted = sorted(set(lst))
print(unique_sorted[1])

# %%
# 40)Write a Python program to get unique values from a list
lst = [1, 2, 2, 3, 4, 4]
unique = list(set(lst))

print(unique)

# %%
# 41)Write a Python program to check whether a list contains a sub list
def is_sublist(main, sub):
    for i in range(len(main) - len(sub) + 1):
        if main[i:i+len(sub)] == sub:
            return True
    return False

print(is_sublist([1, 2, 3, 4], [2, 3]))

# %%
# 42)Write a Python program to split a list into different variables.
lst = [10, 20, 30]

a, b, c = lst

print(a, b, c)

# %% [markdown]
# 43) What is tuple? Difference between list and tuple.
# Ans. Tuple is collection of ordered and immutable elements. the only difference between list and tuple is List is mutable and tuple is immutable.

# %%
# 44)Write a Python program to create a tuple with different data types.
tup = ("hello", 12, True, None)

# %%
# 45)Write a Python program to unzip a list of tuples into individual lists.
pairs = [(1, 'a'), (2, 'b'), (3, 'c')]

nums, chars = zip(*pairs)

print(list(nums))
print(list(chars))

# %%
# 46) Write a Python program to convert a list of tuples into a dictionary.
pairs = [(1, 'a'), (2, 'b'), (3, 'c')]

result = dict(pairs)

print(result)

# %%
# 47) How will you create a dictionary using tuples in python?
keys = (1, 2, 3)
values = ('a', 'b', 'c')

result = dict(zip(keys, values))

print(result)

# %%
# 48) Write a Python script to sort (ascending and descending) a dictionary by value.
data = {'a': 3, 'b': 1, 'c': 2}

# ascending
asc = dict(sorted(data.items(), key=lambda x: x[1]))

# descending
desc = dict(sorted(data.items(), key=lambda x: x[1], reverse=True))

print("Ascending:", asc)
print("Descending:", desc)

# %%
# 49) Write a Python script to concatenate following dictionaries to create a new one.
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}

result = d1.copy()
result.update(d2)

print(result)

# %%
# 50) Write a Python script to check if a given key already exists in a dictionary.
d1 = {'a': 1}
d2 = {'b': 2}

result = {**d1, **d2}

print(result)

# %% [markdown]
# 51) How Do You Traverse Through a Dictionary Object in Python?
# Ans. We can travarse through dictonary object with for loop and values() function of dictonary.
#
# 52) How Do You Check the Presence of a Key in A Dictionary?
# Ans. by using Contains Key. It is most common way to check if a key exists or not in dictionary.

# %%
# 53)Write a Python script to print a dictionary where the keys are numbers between 1 and 15.
result = {}

for i in range(1, 16):
    result[i] = i * i   

print(result)

# %%
# 54)Write a Python program to check multiple keys exists in a dictionary
my_dict = {'a': 1, 'b': 2, 'c': 3}

keys_to_check = ['a', 'b']

if all(key in my_dict for key in keys_to_check):
    print("All keys exist")
else:
    print("Some keys are missing")

# %%
    # 55)Write a Python script to merge two Python dictionaries
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}

merged_dict = {**dict1, **dict2}
print(merged_dict)

# %%
# 56)Write a Python program to map two lists into a dictionary
# Sample output: Counter ({'a': 400, 'b': 400,’d’: 400, 'c': 300}).
from collections import Counter

keys = ['a', 'b', 'c', 'd']
values = [400, 400, 300, 400]

result = Counter(dict(zip(keys, values)))
print(result)

# %%
# 57)Write a Python program to find the highest 3 values in a dictionary
my_dict = {'a': 100, 'b': 300, 'c': 200, 'd': 400, 'e': 250}

top_3 = sorted(my_dict.values(), reverse=True)[:3]
print(top_3)

# %%
# 58)Write a Python program to combine values in python list of dictionaries.
# Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount':
# 300}, o {'item': 'item1', 'amount': 750}]
# Expected Output:
# • Counter ({'item1': 1150, 'item2': 300})
from collections import Counter

data = [
    {'item': 'item1', 'amount': 400},
    {'item': 'item2', 'amount': 300},
    {'item': 'item1', 'amount': 750}
]

result = Counter()

for d in data:
    result[d['item']] += d['amount']

print(result)

# %%
# 59)Write a Python program to create a dictionary from a string.
# Note: Track the count of the letters from the string.
# 60)Sample string:
#  'w3resource' Expected output:
# • {'3': 1,’s’: 1, 'r': 2, 'u': 1, 'w': 1, 'c': 1, 'e': 2, 'o': 1}
from collections import Counter

string = 'w3resource'

result = Counter(string)
print(result)

# %%
# 61)Write a Python function to calculate the factorial of a number (a non-negative integer)
def fact(num):
    if num == 1:
        return 1
    return num * fact(num-1)

num = int(input("enter the number:"))

if num > 0  :
    print("factorial:",fact(num))
else:
    print("negative value")

# %%
# 62)Write a Python function to check whether a number is in a given range
def check_range(num):
    lst = []
    for i in range(101):
        lst.append(i)
        i += 1
    if num in lst :
            print("number is in the range.")
    else :
        print("not in the range")

num = int(input("enter the number:"))

check_range(num)

# %%
# 63)Write a Python function to check whether a number is perfect or not.
p_no = [6, 28, 496, 8128, 33550336, 8589869056, 137438691328]
num = int(input("enter the number:"))
if num in p_no :
    print("Given number is the perfect number.... ")
else:
    print("not a prefect number.... ")

# %%
# 64)Write a Python function that  passed string ichecks whether as palindrome or not
st = input("enter the  string:")

if st == st[::-1]:
    print("string is palindrome...")
else :
    print("not palindrome...")

# %% [markdown]
# 65) How Many Basic Types of Functions Are Available in Python?
# Ans. There is 4 type of function in python.
#         1. Built in function
#         2. User defined function
#         3. Lambda function
#         4. Recursion function

# %%
# 66) How can you pick a random item from a list or tuple?
import numpy as np
arr = [1,3,5,7,9]
tup = (3,8,9,0,5,3)
arr1 = np.random.choice(arr, 1)
arr2 = np.random.choice(tup, 1)
print(arr1)
print(arr2)

# %%
# 67) How can you pick a random item from a range?
# for 1 to 20 range
print(np.random.randint(1,20,5))

# %%
# 68) How can you get a random number in python?
# Ans. With help of random function
arr = np.random.rand(3)
print(arr)

# %% [markdown]
# 69) How will you set the starting value in generating random numbers?
# Ans. We can set intialisation value with seed function random.seed() which is built in function in Random module

# %%
# 70) How will you randomize the items of a list in place?
#Ans. With shuffle function 
lst = [10, 20, 30, 40, 50]
random.shuffle(lst)
print(lst)

# %% [markdown]
# 71) What is File function in python? What are keywords to create and write file.
# Ans. the key function in file is open() which allow you to open the file. it takes 2 parameter file name and mode.

# %%
# 72)Write a Python program to read an entire text file.
with open (r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt","r") as file :
    content = file.read()
    print(content)
    file.close()

# %%
# 73)Write a Python program to append text to a file and display the text.
with open (r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt","a") as file :
    file.write("Pollution is a myth\n")
    file.close()
with open (r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt","r") as file :
    content = file.read()
    print(content)
    file.close()

# %%
# 74)Write a Python program to read first n lines of a file.
n = 1 

with open(r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt", "r") as file:
    for i, line in enumerate(file):
        if i < n:
            print(line.strip())
        else:
            break

# %%
# 75)Write a Python program to read last n lines of a file.
def lines(file_name, n):
    with open(file_name, 'r') as file:
        lines = file.readlines()
        last_lines = lines[-n:]
        for line in last_lines:
            print(line.strip())

lines(r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt", 3)

# %%
# 76)Write a Python program to read a file line by line and store it into a list
file_name = r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt"

with open(file_name, 'r') as file:
    lines_list = file.readlines()

lines_list = [line.strip() for line in lines_list]

print(lines_list)

# %%
# 77)Write a Python program to read a file line by line store it into a variable.
file_name = r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt"
with open(file_name, 'r') as file:
    content = file.read()

print(content)

# %%
# 78)Write a python program to find the longest words.
text = input("Enter a sentence: ")

words = text.split()
max_len = max(len(word) for word in words)

longest_words = [word for word in words if len(word) == max_len]

print("Longest word:", longest_words)

# %%
# 79)Write a Python program to count the number of lines in a text file.
with open(r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt", "r") as f:
    lines = f.readlines()

print("Number of lines:", len(lines))

# %%
# 80)Write a Python program to count the frequency of words in a file.
from collections import Counter
with open(r"C:\Users\Mehul\OneDrive\Documents\TOPS\Python\temp.txt", "r") as f:
    text = f.read().lower()

words = text.split()
freq = Counter(words)

print("Word Frequency:")
for word, count in freq.items():
    print(word, ":", count)

# %%
# 81)Write a Python program to write a list to a file.
data = ["Python", "Java", "C++", "JavaScript"]

with open("output.txt", "w") as f:
    for item in data:
        f.write(item + "\n")

print("List written to file.")

# %%
# 82)Write a Python program to copy the contents of a file to another file.
with open("source.txt", "r") as src:
    content = src.read()

with open("destination.txt", "w") as dest:
    dest.write(content)

print("File copied successfully.")

# %% [markdown]
# 83) Explain Exception handling? What is an Error in Python?
# Ans. Error is an issue that disrupts the normal execution of a program. Exception handling in Python is a mechanism used to manage runtime errors, allowing a program to respond to unexpected events without crashing.
#
# 84) How many except statements can a try-except block have? Name Some built-in exception classes:
# Ans. Exception handling in Python is a mechanism used to manage runtime errors, allowing a program to respond to unexpected events without crashing.
# Value error, Type error, filenotfound error, key error, import error, index error, attribute error
#
# 85) When will the else part of try-except-else be executed?
# Ans. "Else" is executed after the Try code block.
#
# 86) Can one block of except statements handle multiple exception?
# Ans. Yes,a single Except block can handle multiple exceptions by grouping them into a tuple
#
# 87) When is the finally block executed?
# Ans. It excuted at last after try and except block. and it will always excuted no mattern try block runs or except block runs.
#
# 88) What happens when "1" == 1 is executed?
# Ans. Output will be False because "1" is string and 1 is integear.

# %%
# 89)How Do You Handle Exceptions with Try/Except/Finally in Python?
# Explain with coding snippets.
num1 = int(input("Enter First number for division:"))
num2 = int(input("Enter Second number for division:"))
try :
    print("division:", num1/num2)
except ZeroDivisionError :
    print("Can not be divided by Zero...")
finally :
    print("Division completed")
# Out:
# division: 3.0
# Division completed

# %%
# 90)Write python program that user to enter only odd numbers, else will raise an exception. 
class notoddnumber(Exception):
    pass

num = int(input("enter the number:"))

if num % 2 != 0 :
    print("Given number is odd number...")
else :
    raise notoddnumber()
# Out:
# ---------------------------------------------------------------------------
# notoddnumber                              Traceback (most recent call last)
# Cell In[20], line 10
#       8     print("Given number is odd number...")
#       9 else :
# ---> 10     raise notoddnumber()
#
# notoddnumber:
